# %%
import torch
from torch import nn
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.12.0+cpu'

# %%
Class regression(nn.modules):
    super().__init__()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 torch.tensor()
#
# TypeError: tensor() missing 1 required positional arguments: "data"
