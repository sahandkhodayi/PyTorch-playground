# %% [markdown]
# ## main libraries

# %%
import torch
from torch import nn

# vision
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

import matplotlib.pyplot as plt

# %% [markdown]
# # dataset

# %%
training_data=datasets.FashionMNIST(
    root="data", # location 
    train=True, # bool -> for training or test
    download=True,
    transform=ToTensor(), # turning or transforing images PLT -> tensor
    target_transform=None # even output can convet to a tensor
)


testing_data=datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
        

)

# %%
image , lable=training_data[100]

# image ---> the actual metrice of the image with PIL tensor format
# lable ---> it is an int that shows which object it is range:[0, len of classs-1]
image.shape , lable
# if [3,h,w] then ---> a 3d cube that z is color of  and rgb but 
#1 means a black and white picture
# Out:
# (torch.Size([1, 28, 28]), 8)

# %%
len(training_data)
# Out:
# 60000

# %%
Label_names=training_data.classes
Label_names.__len__(),Label_names
# Out:
# (10,
#  ['T-shirt/top',
#   'Trouser',
#   'Pullover',
#   'Dress',
#   'Coat',
#   'Sandal',
#   'Shirt',
#   'Sneaker',
#   'Bag',
#   'Ankle boot'])

# %% [markdown]
# # visual

# %%
plt.imshow(image.squeeze(),cmap="plasma")
plt.title(Label_names[lable])
# Out:
# Text(0.5, 1.0, 'Bag')

# %% [markdown]
# ## dataloader

# %%
from torch.utils.data import DataLoader


BATCH=32 

# spliting datas to ---> small batches
training_dataloader=DataLoader(training_data,
                               batch_size=BATCH,
                               shuffle=True)


testing_dataloader=DataLoader(testing_data,
                               batch_size=BATCH,
                               shuffle=False)

f"{training_dataloader.__len__()} of {BATCH} batches"
# Out:
# '1875 of 32 batches'

# %% [markdown]
# # model 0

# %%
class Fashion(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            nn.Flatten(), # converting [height , width] --> [ height * width]
            nn.Linear(in_features=input_shape, out_features=hidden_units), # in_features = number of features in a data sample (784 pixels)
            nn.Linear(in_features=hidden_units, out_features=output_shape)
        )
    
    def forward(self, x):
        return self.layer_stack(x) 
# input is 784 ---> 28 * 28
#output is len(lable_class)

model_0=Fashion(input_shape=784,
               hidden_units=10,
               output_shape=10)
model_0.to("cpu")
# Out:
# Fashion(
#   (layer_stack): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=10, bias=True)
#     (2): Linear(in_features=10, out_features=10, bias=True)
#   )
# )

# %%
import requests
from pathlib import Path 

# Download helper functions from Learn PyTorch repo (if not already downloaded)
if Path("helper_functions.py").is_file():
  print("helper_functions.py already exists, skipping download")
else:
  print("Downloading helper_functions.py")
  # Note: you need the "raw" GitHub URL for this to work
  request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
  with open("helper_functions.py", "wb") as f:
    f.write(request.content)
# Out:
# helper_functions.py already exists, skipping download

# %%
from helper_functions import accuracy_fn

loss_func=nn.CrossEntropyLoss()# need notes for this loss func
optim=torch.optim.SGD(params=model_0.parameters(),
                      lr=0.1)

# %%
from tqdm.auto import tqdm
epochs= 4


for epoch in tqdm(range(epochs)):
    train_loss=0
    # trining through batches
    for batch,(X,y) in enumerate(training_dataloader):
        model_0.train()

        y_predict=model_0(X)
        loss=loss_func(y_predict,y)

        train_loss+=loss

        optim.zero_grad()

        loss.backward()

        optim.step()

        if batch % 1000 == 0:
            print(f"Looked at {batch * len(X)}/{len(training_dataloader)} samples")
    train_loss /= len(training_dataloader)
    test_loss,test_acc=0, 0
    
    model_0.eval()
    with torch.inference_mode():
        for X,y in testing_dataloader:
            test_predict=model_0(X)

            test_loss +=loss_func(test_predict,y)
            test_acc +=accuracy_fn(y_true=y, y_pred=test_predict.argmax(dim=1))

            test_loss/= len(testing_dataloader)
            test_acc/= len(testing_dataloader)
            print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Looked at 0/1875 samples
# Looked at 32000/1875 samples
#
# Train loss: 0.58285 | Test loss: 0.00162, Test acc: 0.24%
#
#
# Train loss: 0.58285 | Test loss: 0.00157, Test acc: 0.24%
#
#
# Train loss: 0.58285 | Test loss: 0.00162, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00075, Test acc: 0.30%
#
#
# Train loss: 0.58285 | Test loss: 0.00168, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00064, Test acc: 0.30%
#
#
# Train loss: 0.58285 | Test loss: 0.00111, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00232, Test acc: 0.23%
#
#
# Train loss: 0.58285 | Test loss: 0.00148, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00136, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00133, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00143, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00138, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00106, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00239, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00171, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00117, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00206, Test acc: 0.21%
#
#
# Train loss: 0.58285 | Test loss: 0.00145, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00295, Test acc: 0.24%
#
#
# Train loss: 0.58285 | Test loss: 0.00200, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00181, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00233, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00130, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00073, Test acc: 0.30%
#
#
# Train loss: 0.58285 | Test loss: 0.00135, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00128, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00128, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00184, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00140, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00283, Test acc: 0.22%
#
#
# Train loss: 0.58285 | Test loss: 0.00164, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00137, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00139, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00204, Test acc: 0.24%
#
#
# Train loss: 0.58285 | Test loss: 0.00119, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00186, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00167, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00214, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00166, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00198, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00159, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00180, Test acc: 0.23%
#
#
# Train loss: 0.58285 | Test loss: 0.00135, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00062, Test acc: 0.30%
#
#
# Train loss: 0.58285 | Test loss: 0.00176, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00173, Test acc: 0.24%
#
#
# Train loss: 0.58285 | Test loss: 0.00163, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00102, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00138, Test acc: 0.27%
#
#
# Train loss: 0.58285 | Test loss: 0.00127, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00262, Test acc: 0.23%
#
#
# Train loss: 0.58285 | Test loss: 0.00056, Test acc: 0.31%
#
#
# Train loss: 0.58285 | Test loss: 0.00146, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00222, Test acc: 0.25%
#
#
# Train loss: 0.58285 | Test loss: 0.00132, Test acc: 0.28%
#
#
# Train loss: 0.58285 | Test loss: 0.00167, Test acc: 0.26%
#
#
# Train loss: 0.58285 | Test loss: 0.00221, Test acc: 0.23%
#
#
# Train loss: 0.58285 | Test loss: 0.00067, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00105, Test acc: 0.29%
#
#
# Train loss: 0.58285 | Test loss: 0.00144, Test acc: 0.27%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 29
#      25     test_loss,test_acc=0, 0
#      26
#      27     model_0.eval()
#      28     with torch.inference_mode():
# ---> 29         for X,y in testing_dataloader:
#      30             test_predict=model_0(X)
#      31
#      32             test_loss +=loss_func(test_predict,y)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\data\dataloader.py:725, in _BaseDataLoaderIter.__next__(self)
#     722 if self._sampler_iter is None:
#     723     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     724     self._reset()  # type: ignore[call-arg]
# --> 725 data = self._next_data()
#     726 self._num_yielded += 1
#     727 if (
#     728     self._dataset_kind == _DatasetKind.Iterable
#     729     and self._IterableDataset_len_called is not None
#     730     and self._num_yielded > self._IterableDataset_len_called
#     731 ):
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\data\dataloader.py:785, in _SingleProcessDataLoaderIter._next_data(self)
#     783 def _next_data(self):
#     784     index = self._next_index()  # may raise StopIteration
# --> 785     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     786     if self._pin_memory:
#     787         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
# ---> 54         data = [self.dataset[idx] for idx in possibly_batched_index]
#      55 else:
#      56     data = self.dataset[possibly_batched_index]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\datasets\mnist.py:146, in MNIST.__getitem__(self, index)
#     143 img = _Image_fromarray(img.numpy(), mode="L")
#     145 if self.transform is not None:
# --> 146     img = self.transform(img)
#     148 if self.target_transform is not None:
#     149     target = self.target_transform(target)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\transforms\transforms.py:137, in ToTensor.__call__(self, pic)
#     129 def __call__(self, pic):
#     130     """
#     131     Args:
#     132         pic (PIL Image or numpy.ndarray): Image to be converted to tensor.
#    (...)    135         Tensor: Converted image.
#     136     """
# --> 137     return F.to_tensor(pic)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\torchvision\transforms\functional.py:174, in to_tensor(pic)
#     172 img = img.view(pic.size[1], pic.size[0], F_pil.get_image_num_channels(pic))
#     173 # put it from HWC to CHW format
# --> 174 img = img.permute((2, 0, 1)).contiguous()
#     175 if isinstance(img, torch.ByteTensor):
#     176     return img.to(dtype=default_float_dtype).div(255)
#
# KeyboardInterrupt:

# %% [markdown]
# ### normal nns wont work for picuter inputs as you can see acc is pretty low
# solution ? use CNN

# %% [markdown]
# ## CNN

# %%
class Fashion1(nn.Module):

    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape, 
                      out_channels=hidden_units, 
                      kernel_size=3, 
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units, 
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from? 
            # It's because each layer of our network compresses and changes the shape of our input data.
            nn.Linear(in_features=hidden_units*7*7, 
                      out_features=output_shape)
        )
    
    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x
  
model=Fashion1(input_shape=1,
              hidden_units=10,
              output_shape=len(Label_names))   
model
# Out:
# Fashion1(
#   (block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %%
optimizer=torch.optim.SGD(params=model.parameters(),
                      lr=0.1)

device="cpu"

# %%
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               accuracy_fn,
               device: torch.device = device):
    train_loss, train_acc = 0, 0
    model.to(device)
    for batch, (X, y) in enumerate(data_loader):
        # Send data to GPU
        X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss
        train_acc += accuracy_fn(y_true=y,
                                 y_pred=y_pred.argmax(dim=1)) # Go from logits -> pred labels

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

    # Calculate loss and accuracy per epoch and print out what's happening
    train_loss /= len(data_loader)
    train_acc /= len(data_loader)
    print(f"Train loss: {train_loss:.5f} | Train accuracy: {train_acc:.2f}%")

def test_step(data_loader: torch.utils.data.DataLoader,
              model: torch.nn.Module,
              loss_fn: torch.nn.Module,
              accuracy_fn,
              device: torch.device = device):
    test_loss, test_acc = 0, 0
    model.to(device)
    model.eval() # put model in eval mode
    # Turn on inference context manager
    with torch.inference_mode(): 
        for X, y in data_loader:
            # Send data to GPU
            X, y = X.to(device), y.to(device)
            
            # 1. Forward pass
            test_pred = model(X)
            
            # 2. Calculate loss and accuracy
            test_loss += loss_fn(test_pred, y)
            test_acc += accuracy_fn(y_true=y,
                y_pred=test_pred.argmax(dim=1) # Go from logits -> pred labels
            )
        
        # Adjust metrics and print out
        test_loss /= len(data_loader)
        test_acc /= len(data_loader)
        print(f"Test loss: {test_loss:.5f} | Test accuracy: {test_acc:.2f}%\n")

# %%
from timeit import default_timer as timer
train_time_start_model_2 = timer()

epochs=3

for epoch in tqdm(range(epochs)):
    train_step(data_loader=training_dataloader,
               model=model,
               loss_fn=loss_func,
               optimizer=optimizer,
               accuracy_fn=accuracy_fn,
               device=device
              )

    test_step(data_loader=testing_dataloader,
               model=model,
               loss_fn=loss_func,
               accuracy_fn=accuracy_fn,
               device=device
             )

train_time_end_model_2 = timer()
total_train_time_model_2 = print_train_time(start=train_time_start_model_2,
                                           end=train_time_end_model_2,
                                           device=device)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Train loss: 0.29073 | Train accuracy: 89.41%
# Test loss: 0.30984 | Test accuracy: 88.93%
#
# Train loss: 0.28184 | Train accuracy: 89.80%
# Test loss: 0.32383 | Test accuracy: 88.17%
#
# Train loss: 0.27601 | Train accuracy: 89.95%
# Test loss: 0.31417 | Test accuracy: 88.69%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 23
#      19                device=device
#      20              )
#      21
#      22 train_time_end_model_2 = timer()
# ---> 23 total_train_time_model_2 = print_train_time(start=train_time_start_model_2,
#      24                                            end=train_time_end_model_2,
#      25                                            device=device)
#
# NameError: name 'print_train_time' is not defined
